# %%
EDA _ Analise Exploratorias de Dados 

Etapas 1 - Carregamento do DataSet

Etapa 2 - Limpeza dos dados (Retirada a coluna Enderço do Canal(por sr uma url e não  trazer  beneficio))

Etapa 3 - Definir colunas X e y para  mostrar  qual o canal tem mais incritos 

Etapa 4 - Criar umn Grafico   Matplotlib de barras 

Os dados X e Y e uma Legenda Y e um Titulo
