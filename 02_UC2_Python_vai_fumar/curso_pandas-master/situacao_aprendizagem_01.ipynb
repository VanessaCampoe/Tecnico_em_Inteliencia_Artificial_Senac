# %% [markdown]
# # EDA _ Análise Exploratória de Dadoss

# %% [markdown]
# ### Etapa 1 - Carregamento do DataSet

# %%
# !pip install pandas
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: pandas in c:\users\vanessa34180026\appdata\roaming\python\python312\site-packages (2.3.2)
# Requirement already satisfied: numpy>=1.26.0 in c:\users\vanessa34180026\appdata\roaming\python\python312\site-packages (from pandas) (2.3.3)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\vanessa34180026\appdata\roaming\python\python312\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\vanessa34180026\appdata\roaming\python\python312\site-packages (from pandas) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\vanessa34180026\appdata\roaming\python\python312\site-packages (from pandas) (2025.2)
# Requirement already satisfied: six>=1.5 in c:\users\vanessa34180026\appdata\roaming\python\python312\site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)

# %%
import pandas as pd

# %%
# Supondo que seu arquivo salvo se chame 'canais.csv' e use VÍRGULA como delimitador
df = pd.read_csv('datasets/canaisnerds.csv', delimiter=';', encoding='utf-8')

# %%
df
# Out:
#                    canal                                          descrição  \
# 0       Pipoca e Nanquim  Conteúdo sobre HQs, quadrinhos, livros e cultu...
# 1          Coisa de Nerd  Vídeos de curiosidades, ciência, desafios e re...
# 2               Naruhodo  Podcast com a missão de usar a ciência para ex...
# 3               GugaCast  Canal do podcast GugaCast, focado em entrevist...
# 4            Peixe Babel  Curiosidades sobre zoologia, biologia, e o mun...
# 5       Ciência Toda Dia  Canal totalmente voltado para assuntos que pod...
# 6             Bola Presa  Canal do blog Bola Presa, focado em notícias, ...
# 7            Rebobinando  Canal sobre filmes, séries, cultura pop, nosta...
# 8          Xadrez Brasil  Conteúdo sobre xadrez, aulas, partidas e análi...
# 9               99 Vidas  Canal e podcast com foco em games retrô, nosta...
# 10                Gaveta  Conteúdo focado em edição de vídeo, VFX, audio...
# 11  Programação Dinâmica  Conteúdo sobre ciência de dados, programação, ...
# 12       Código Fonte TV  Canal de um casal de programadores apaixonados...
# 13        Átila Iamarino  Conteúdo de divulgação científica, principalme...
# 14       Manual do Mundo  Experiências, curiosidades e tutoriais de "Faç...
# 15    Rafaella Ballerini  Conteúdo sobre programação, tecnologia, carrei...
# 16          Dev Soutinho  Vídeos sobre desenvolvimento de software, test...
# 17         Vinicius Dias  Canal focado em desenvolvimento de software, c...
# 18      Felipe Deschamps  Conteúdo sobre programação, desenvolvimento e ...
# 19            Jovem Nerd  Canal de cultura pop, games, filmes, séries, q...
# 20              Canal 90  Conteúdo sobre a cultura pop e nostalgia dos a...
# 21        Café e Ciência  Divulgação científica e curiosidades do dia a ...
# 22            Cronosfera  Canal focado em astronomia, espaço, curiosidad...
# 23      Simara Conceição  Conteúdo sobre programação, carreira e inclusã...
# 24             Futurices  Conteúdo sobre games, cinema, ficção científic...
# 25              Gemaplys  Vídeos de comédia e animações com humor peculiar.
# 26                Kennzy  Conteúdo de games, principalmente League of Le...
# 27              Nautilus  Focado em games, análises, gameplays e debates...
# 28         O Programador  Aulas e tutoriais de programação e desenvolvim...
# 29         Sidao do Game             Conteúdo de games, gameplay e reações.
# 30           Space Orbit  Canal sobre exploração espacial, foguetes, ast...
# 31        Thiago Romariz  Conteúdo sobre cinema, séries, cultura pop, no...
# 32                 Luide  Focado em análise de conteúdo e formação de cr...
#
#                                          endereço  \
# 0         https://www.youtube.com/@pipocaenanquim
# 1   https://www.youtube.com/@republicacoisadenerd
# 2          https://www.youtube.com/@CanalNaruhodo
# 3        https://www.youtube.com/@gugacastpodcast
# 4             https://www.youtube.com/@peixebabel
# 5         https://www.youtube.com/@CienciaTodoDia
# 6              https://www.youtube.com/@bolapresa
# 7            https://www.youtube.com/@Rebobinando
# 8           https://www.youtube.com/@xadrezbrasil
# 9              https://www.youtube.com/@99vidasBr
# 10                https://www.youtube.com/@gaveta
# 11   https://www.youtube.com/@ProgramacaoDinamica
# 12         https://www.youtube.com/@codigofontetv
# 13         https://www.youtube.com/@atilalamarino
# 14        https://www.youtube.com/c/manualdomundo
# 15     https://www.youtube.com/@RafaellaBallerini
# 16          https://www.youtube.com/c/DevSoutinho
# 17          https://www.youtube.com/@viniciusdias
# 18      https://www.youtube.com/c/FilipeDeschamps
# 19            https://www.youtube.com/c/JovemNerd
# 20               https://www.youtube.com/@canal90
# 21          https://www.youtube.com/@CafeeCiencia
# 22            https://www.youtube.com/@Cronosfera
# 23       https://www.youtube.com/@SimaraConceicao
# 24             https://www.youtube.com/@Futurices
# 25              https://www.youtube.com/@GEMAPLYS
# 26                https://www.youtube.com/@Kennzy
# 27      https://www.youtube.com/user/nautiluslink
# 28          https://www.youtube.com/@oprogramador
# 29           https://www.youtube.com/@SidaodoGame
# 30            https://www.youtube.com/@SpaceOrbit
# 31         https://www.youtube.com/@thiagoromariz
# 32                 https://www.youtube.com/@luide
#
#                         categoria qtde_inscritos (aprox.)  conhece_canal
# 0          Quadrinhos/Cultura Pop                   1.81M              0
# 1     Curiosidades/Entretenimento                   2.55M              0
# 2            Ciência/Curiosidades                    441K              0
# 3               Podcast/Histórias                     60K              0
# 4                Ciência/Biologia                    412K              0
# 5            Ciência/Curiosidades                   7.49M              0
# 6                    Esportes/NBA                   34.7K              0
# 7              Cultura Pop/Cinema                    549K              0
# 8                 Esportes/Xadrez                    158K              0
# 9                 Games/Nostalgia                    129K              0
# 10             Audiovisual/Edição                    700K              0
# 11            Tecnologia/Educação                    358K              0
# 12         Tecnologia/Programação                    746K              0
# 13               Ciência/Biologia                   1.15M              0
# 14   Curiosidades/Faça Você Mesmo                   19.8M              0
# 15         Tecnologia/Programação                    599K              0
# 16         Tecnologia/Programação                    114K              0
# 17         Tecnologia/Programação                    200K              0
# 18         Tecnologia/Programação                   1.54M              0
# 19     Cultura Pop/Entretenimento                    3.5M              0
# 20          Nostalgia/Cultura Pop                    647K              0
# 21           Ciência/Curiosidades                    165K              0
# 22             Ciência/Astronomia                    557K              0
# 23         Tecnologia/Programação                   16.5K              0
# 24  Cultura Pop/Ficção Científica                    285K              0
# 25         Entretenimento/Comédia                   1.64M              0
# 26                  Games/eSports                    311K              0
# 27           Games/Entretenimento                    158K              0
# 28         Tecnologia/Programação                    319K              0
# 29           Games/Entretenimento                     39K              0
# 30                 Ciência/Espaço                   1.67M              0
# 31             Cultura Pop/Cinema                    511K              0
# 32        Entretenimento/Creators                   83.9K              0

# %%
df.head()
# Out:
#               canal                                          descrição  \
# 0  Pipoca e Nanquim  Conteúdo sobre HQs, quadrinhos, livros e cultu...
# 1     Coisa de Nerd  Vídeos de curiosidades, ciência, desafios e re...
# 2          Naruhodo  Podcast com a missão de usar a ciência para ex...
# 3          GugaCast  Canal do podcast GugaCast, focado em entrevist...
# 4       Peixe Babel  Curiosidades sobre zoologia, biologia, e o mun...
#
#                                         endereço                    categoria  \
# 0        https://www.youtube.com/@pipocaenanquim       Quadrinhos/Cultura Pop
# 1  https://www.youtube.com/@republicacoisadenerd  Curiosidades/Entretenimento
# 2         https://www.youtube.com/@CanalNaruhodo         Ciência/Curiosidades
# 3       https://www.youtube.com/@gugacastpodcast            Podcast/Histórias
# 4            https://www.youtube.com/@peixebabel             Ciência/Biologia
#
#   qtde_inscritos (aprox.)  conhece_canal
# 0                   1.81M              0
# 1                   2.55M              0
# 2                    441K              0
# 3                     60K              0
# 4                    412K              0

# %% [markdown]
# ### Etapa 2 - Limpeza dos Dados (Retirar a Coluna Endereço do Canal (por ser uma url e não trazer beneficio))

# %%
# quero criar um novo dataframe que vai retirar a coluna endereço do canal
df_novo = df.drop(columns=['endereço'])

# %%
# quero renomear a coluna qtde_inscritos(aprox.) para qtde_inscritos
df_novo = df_novo.rename(columns={'qtde_inscritos (aprox.)': 'qtde_inscritos'})
# nao renomeou que erro ocorreu aruma ai
df_novo.head()
# Out:
#               canal                                          descrição  \
# 0  Pipoca e Nanquim  Conteúdo sobre HQs, quadrinhos, livros e cultu...
# 1     Coisa de Nerd  Vídeos de curiosidades, ciência, desafios e re...
# 2          Naruhodo  Podcast com a missão de usar a ciência para ex...
# 3          GugaCast  Canal do podcast GugaCast, focado em entrevist...
# 4       Peixe Babel  Curiosidades sobre zoologia, biologia, e o mun...
#
#                      categoria qtde_inscritos  conhece_canal
# 0       Quadrinhos/Cultura Pop          1.81M              0
# 1  Curiosidades/Entretenimento          2.55M              0
# 2         Ciência/Curiosidades           441K              0
# 3            Podcast/Histórias            60K              0
# 4             Ciência/Biologia           412K              0

# %%
df_novo.head()
# Out:
#               canal                                          descrição  \
# 0  Pipoca e Nanquim  Conteúdo sobre HQs, quadrinhos, livros e cultu...
# 1     Coisa de Nerd  Vídeos de curiosidades, ciência, desafios e re...
# 2          Naruhodo  Podcast com a missão de usar a ciência para ex...
# 3          GugaCast  Canal do podcast GugaCast, focado em entrevist...
# 4       Peixe Babel  Curiosidades sobre zoologia, biologia, e o mun...
#
#                      categoria qtde_inscritos  conhece_canal
# 0       Quadrinhos/Cultura Pop          1.81M              0
# 1  Curiosidades/Entretenimento          2.55M              0
# 2         Ciência/Curiosidades           441K              0
# 3            Podcast/Histórias            60K              0
# 4             Ciência/Biologia           412K              0

# %%
# crie um novo dataframe apenas com as colunas canal e qtde_inscritos
df_novo_frame = df_novo[['canal', 'qtde_inscritos']]   # aqiui dentro desse colchete e o data freme

# %%
df_novo_frame
# Out:
#                    canal qtde_inscritos
# 0       Pipoca e Nanquim          1.81M
# 1          Coisa de Nerd          2.55M
# 2               Naruhodo           441K
# 3               GugaCast            60K
# 4            Peixe Babel           412K
# 5       Ciência Toda Dia          7.49M
# 6             Bola Presa          34.7K
# 7            Rebobinando           549K
# 8          Xadrez Brasil           158K
# 9               99 Vidas           129K
# 10                Gaveta           700K
# 11  Programação Dinâmica           358K
# 12       Código Fonte TV           746K
# 13        Átila Iamarino          1.15M
# 14       Manual do Mundo          19.8M
# 15    Rafaella Ballerini           599K
# 16          Dev Soutinho           114K
# 17         Vinicius Dias           200K
# 18      Felipe Deschamps          1.54M
# 19            Jovem Nerd           3.5M
# 20              Canal 90           647K
# 21        Café e Ciência           165K
# 22            Cronosfera           557K
# 23      Simara Conceição          16.5K
# 24             Futurices           285K
# 25              Gemaplys          1.64M
# 26                Kennzy           311K
# 27              Nautilus           158K
# 28         O Programador           319K
# 29         Sidao do Game            39K
# 30           Space Orbit          1.67M
# 31        Thiago Romariz           511K
# 32                 Luide          83.9K

# %% [markdown]
# ### Etapa 3 - Definir as colunas X e Y para mostrar qual o canal tem mais inscritos

# %%
# vamos definir o grafico x é o canal e y é o número de inscritos
import matplotlib.pyplot as plt
plt.figure(figsize=(20,12))
plt.bar(df_novo['canal'], df_novo['qtde_inscritos'], color='blue')
plt.xlabel('Canal') 
plt.ylabel('Número de Inscritos')
plt.title('Número de Inscritos por Canal Nerd')
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# # Etapa 4 - Simplificar o Eixo Y (Número de Inscritos)

# %%
def converter_inscritos(valor):  # paramentro rece um valor da chamada 
    if isinstance(valor, str):   # aquyi ja e dentro da minha funcao , 
        valor = valor.upper().replace(',', '.')  #  afuncao upper trasnforma em maiusculo  # aquyi  q acontec e o kasten q e uma conversao , um tipo e uma conversao 
        if 'M' in valor:   
            return float(valor.replace('M', '')) * 1_000_000
        elif 'K' in valor:
            return float(valor.replace('K', '')) * 1_000
        elif 'B' in valor:
            return float(valor.replace('B', '')) * 1_000_000_000
    try:
        return float(valor)
    except:
        return 0 # Ou trate o erro como preferir

# Aplique a função ao seu DataFrame
df_novo['qtde_inscritos'] = df_novo['qtde_inscritos'].apply(converter_inscritos)   # aqui estou delegando naquela funcao 
# a coluna vai aplicar a funcao

# %%
df_novo.head()
# Out:
#               canal                                          descrição  \
# 0  Pipoca e Nanquim  Conteúdo sobre HQs, quadrinhos, livros e cultu...
# 1     Coisa de Nerd  Vídeos de curiosidades, ciência, desafios e re...
# 2          Naruhodo  Podcast com a missão de usar a ciência para ex...
# 3          GugaCast  Canal do podcast GugaCast, focado em entrevist...
# 4       Peixe Babel  Curiosidades sobre zoologia, biologia, e o mun...
#
#                      categoria  qtde_inscritos  conhece_canal
# 0       Quadrinhos/Cultura Pop       1810000.0              0
# 1  Curiosidades/Entretenimento       2550000.0              0
# 2         Ciência/Curiosidades        441000.0              0
# 3            Podcast/Histórias         60000.0              0
# 4             Ciência/Biologia        412000.0              0

# %% [markdown]
# ### Etapa 4 - Criar um Gráfico MatplotLib de Barras
# #### Os dados X e Y , Legenda X e uma Legenda Y e um Título

# %%
df_novo = df_novo.sort_values('qtde_inscritos', ascending=True)

# %%
import matplotlib.ticker as ticker

# %%
plt.figure(figsize=(10,10)) # Aumente o tamanho para mais espaço
formatter = ticker.FuncFormatter(lambda x, p: format(int(x), ',').replace(',', '.'))
plt.gca().xaxis.set_major_formatter(formatter)
plt.barh(df_novo['canal'], df_novo['qtde_inscritos'], color='blue')
plt.ylabel('Número de Inscritos (Escala Numérica)')
plt.xlabel('número de inscritos') 
plt.ylabel('canais')
plt.title('Número de Inscritos por Canal Nerd')
plt.tight_layout()

plt.show()

# %%
df_novo.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 33 entries, 23 to 14
# Data columns (total 5 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   canal           33 non-null     object
#  1   descrição       33 non-null     object
#  2   categoria       33 non-null     object
#  3   qtde_inscritos  33 non-null     float64
#  4   conhece_canal   33 non-null     int64
# dtypes: float64(1), int64(1), object(3)
# memory usage: 1.5+ KB

# %%
# o canal que tem mais inscritos
# criando uma condicao mostrar o canal com mais inscritos
canal_mais_inscritos = df_novo.loc[df_novo['qtde_inscritos'].idxmax()]
canal_mais_inscritos
# Out:
# canal                                               Manual do Mundo
# descrição         Experiências, curiosidades e tutoriais de "Faç...
# categoria                              Curiosidades/Faça Você Mesmo
# qtde_inscritos                                           19800000.0
# conhece_canal                                                     0
# Name: 14, dtype: object
