# %%
https://raw.githubusercontent.com/romulodf-cesar/python-datascience/refs/heads/master/datasets/tempo_salarios.csv

# %% [markdown]
# l limpeza
# A analise
# M manipulaçao de dados
# V Visualização

# %% [markdown]
# Modelo , onde vamos cocar os dados , isso como se fosse o chat gpt , assim com os dados eles pode fazer uma previsao
#
# Series

# %% [markdown]
# # Python Data Science
#
# - Instalaçao de pandas
# - Problema
# - Entendimento do problema
# - Carreghamento dos Dados
# - Entendimento  do DataSet
# - Análise Descritiva
#     - População
#     - Amostra
#     - Definição
#     - Medias (Médias, Medianas, Moda, Desvio, Padrão)

# %% [markdown]
# Vetor e Mastriz

# %% [markdown]
# Vetor
#
# - É uma estrutura de dados
# - Porgrama (Matriz/Coleções ) x Cientista de Dados Python (Dataframe)
# - Matriz Unidimencional (vetor)
# - Uma Dimensão (pq sao apenas linhas)
# - Na matematica : matriz linha ou matriz coluna
# - Série: indices
#
#
# (com a quantidade de informaçções ele ultrapassa o 3d e vira multidimencional )

# %% [markdown]
# ### Matriz
# - É uma estrutura de dados
# - Porgrama (Matriz/Coleções ) x Cientista de Dados Python (Dataframe)
# - Matriz Bidimencional (vetor)
# - 2D - duas dimensões ( pq sao linhas e colunas )
# - Datraframe --> df

# %% [markdown]
# imagem

# %% [markdown]
# Em resumo :
#
# Serie x DataFrame
#
# - Series - 1D  serisa uma linha ou coluna , um ou outro
# - Dataframe - 2D  aqui temos os dois , linhas e colunas

# %%
# vamos importsar  o pandas 
! pip install pandas
# Out:
# Requirement already satisfied: pandas in c:\users\vanessa34180026\ia\tecnicointeligencia\.venv\lib\site-packages (2.3.3)
# Requirement already satisfied: numpy>=1.26.0 in c:\users\vanessa34180026\ia\tecnicointeligencia\.venv\lib\site-packages (from pandas) (2.3.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\vanessa34180026\ia\tecnicointeligencia\.venv\lib\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\vanessa34180026\ia\tecnicointeligencia\.venv\lib\site-packages (from pandas) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\vanessa34180026\ia\tecnicointeligencia\.venv\lib\site-packages (from pandas) (2025.2)
# Requirement already satisfied: six>=1.5 in c:\users\vanessa34180026\ia\tecnicointeligencia\.venv\lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# [notice] A new release of pip is available: 24.0 -> 25.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import pandas as pd

# %%
import os
print(os.getcwd())
# Out:
# c:\Users\vanessa34180026\IA\tecnicointeligencia\02_UC2_Python_vai_fumar\05_python_DataScienc\05_python_datasets\datasets

# %%
import pandas as pd
import os

print("Diretório atual:", os.getcwd())
print("Arquivos na pasta atual:", os.listdir())

df = pd.read_csv('tempo_salarios.csv')
print(df.head())
# Out:
# Diretório atual: c:\Users\vanessa34180026\IA\tecnicointeligencia\02_UC2_Python_vai_fumar\05_python_DataScienc\05_python_datasets\datasets
# Arquivos na pasta atual: ['aula.ipynb', 'tempo_salarios.csv']
#    AnosdeExperiencia  Salario
# 0                1.1  39343.0
# 1                1.3  46205.0
# 2                1.5  37731.0
# 3                2.0  43525.0
# 4                2.2  39891.0

# %%
# vamos carregar o datafreme 


df = pd.read_csv('tempo_salarios.csv')

# %%
# cabeçalho 
df.head()
# Out:
#    AnosdeExperiencia  Salario
# 0                1.1  39343.0
# 1                1.3  46205.0
# 2                1.5  37731.0
# 3                2.0  43525.0
# 4                2.2  39891.0
