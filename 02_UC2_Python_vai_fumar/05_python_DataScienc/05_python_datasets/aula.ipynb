# %%
https://raw.githubusercontent.com/romulodf-cesar/python-datascience/refs/heads/master/datasets/tempo_salarios.csv
# Out:
#   Cell In[2], line 1
#     https://raw.githubusercontent.com/romulodf-cesar/python-datascience/refs/heads/master/datasets/tempo_salarios.csv
#           ^
# SyntaxError: invalid syntax

# %% [markdown]
# l limpeza
# A analise
# M manipulaçao de dados
# V Visualização

# %% [markdown]
# Modelo , onde vamos cocar os dados , isso como se fosse o chat gpt , assim com os dados eles pode fazer uma previsao
#
# Series

# %% [markdown]
# # Python Data Science
#
# - Instalaçao de pandas
# - Problema
# - Entendimento do problema
# - Carreghamento dos Dados
# - Entendimento  do DataSet
# - Análise Descritiva
#     - População
#     - Amostra
#     - Definição
#     - Medias (Médias, Medianas, Moda, Desvio, Padrão)

# %% [markdown]
# Vetor e Mastriz

# %% [markdown]
# Vetor
#
# - É uma estrutura de dados
# - Porgrama (Matriz/Coleções ) x Cientista de Dados Python (Dataframe)
# - Matriz Unidimencional (vetor)
# - Uma Dimensão (pq sao apenas linhas)
# - Na matematica : matriz linha ou matriz coluna
# - Série: indices
#
#
# (com a quantidade de informaçções ele ultrapassa o 3d e vira multidimencional )

# %% [markdown]
# ### Matriz
# - É uma estrutura de dados
# - Porgrama (Matriz/Coleções ) x Cientista de Dados Python (Dataframe)
# - Matriz Bidimencional (vetor)
# - 2D - duas dimensões ( pq sao linhas e colunas )
# - Datraframe --> df

# %% [markdown]
# imagem

# %% [markdown]
# Em resumo :
#
# Serie x DataFrame
#
# - Series - 1D  serisa uma linha ou coluna , um ou outro
# - Dataframe - 2D  aqui temos os dois , linhas e colunas

# %%
# vamos importsar  o pandas 
! pip install pandas
# Out:
# ...
# [notice] A new release of pip is available: 24.0 -> 25.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import pandas as pd

# %%
import os
print(os.getcwd())
# Out:
# c:\Users\vanessa34180026\IA\tecnicointeligencia\02_UC2_Python_vai_fumar\05_python_DataScienc

# %%
# vamos importar o pandas
import pandas as pd
import os

print("Diretório atual:", os.getcwd())
print("Arquivos na pasta atual:", os.listdir())

# vamos carregar o dataframe

df = pd.read_csv('datasets/tempo_salarios.csv')

print(df.head())
# Out:
# Diretório atual: c:\Users\vanessa34180026\IA\tecnicointeligencia\02_UC2_Python_vai_fumar\05_python_DataScienc\05_python_datasets
# Arquivos na pasta atual: ['01.ipynb', 'aula.ipynb', 'datasets']
#    AnosdeExperiencia  Salario
# 0                1.1  39343.0
# 1                1.3  46205.0
# 2                1.5  37731.0
# 3                2.0  43525.0
# 4                2.2  39891.0

# %%
# vamos carregar o datafreme 


df = pd.read_csv('datasets/tempo_salarios.csv')

# %%
# cabeçalho 
# vamos carregar o dataframe
df.head()
# Out:
#    AnosdeExperiencia  Salario
# 0                1.1  39343.0
# 1                1.3  46205.0
# 2                1.5  37731.0
# 3                2.0  43525.0
# 4                2.2  39891.0

# %%
df.tail()
# Out:
#     AnosdeExperiencia   Salario
# 25                9.0  105582.0
# 26                9.5  116969.0
# 27                9.6  112635.0
# 28               10.3  122391.0
# 29               10.5  121872.0

# %%
len(df)
# Out:
# 30

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30 entries, 0 to 29
# Data columns (total 2 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   AnosdeExperiencia  30 non-null     float64
#  1   Salario            30 non-null     float64
# dtypes: float64(2)
# memory usage: 612.0 bytes

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Dontpad : tiasenac
#
# #Exercicio
# - copie  e cole a imagfem das variaveis e seus tipos
# - considerado nosso dataset e informe  para turma quais os tipos de variaveis
# #Quantitativas
#  - Discretos:  resultam de um conjunto finito ou enumerável de valores possivel (contagem)
#  - Contínuos: resultam em um número infínito de valores(mensuraçao)
#
#  #Estatística Descritiva
#
#  -Medidas de tendencias Centrais
#  - Medidas de tendencias

# %%
df.describe() # aqui eu chgamo quasse todos os camandos
# Out:
#        AnosdeExperiencia        Salario
# count          30.000000      30.000000
# mean            5.313333   76003.000000
# std             2.837888   27414.429785
# min             1.100000   37731.000000
# 25%             3.200000   56720.750000
# 50%             4.700000   65237.000000
# 75%             7.700000  100544.750000
# max            10.500000  122391.000000

# %% [markdown]
# Séries e Dataframes
#
#
# - As duas estruturas de um objeto Pandas são Series e Dataframes
# - Trocando em miúdos, um objeto Series é um array unidimensional, ou seja, um vetor
# - Por sua vez, um Dataframe é uma matriz bidimensional rotulada, ou seja, para a qual podem ser atríbuidos rótulos (nomes) ao seus atributos (colunas)
# - Essas colunas possuem tipos de dados diferentes
# - Possuem também índices (númericos) às suas linhas
# - Um objeto Series pode ser criado a partir de várias origens diferentes
# - Vamos cria-los?

# %%
# exercicio : fazer um comparativo entre dous dataset
df_faltando = pd.read_csv("datasets/tempo_salarios_incompleto.csv")

# %%
# importando o pandas
import pandas as pd
### Séries e Dataframes
print("Criando uma instância de Series a partir de uma lista")
primeiros_jogos = pd.Series([1952, 1958, 1971, 1972])
print(primeiros_jogos)
# Out:
# Criando uma instância de Series a partir de uma lista
# 0    1952
# 1    1958
# 2    1971
# 3    1972
# dtype: int64

# %%
# qual o tipo
print(type(primeiros_jogos))
# Out:
# <class 'pandas.core.series.Series'>

# %%
# muito bom! vamos criar uma série a partir de um dicionário agora
print("Criando uma instância de Series a partir de um dicionário")
terceiros_jogos = pd.Series({'a': 1996, 'b': 2000, 'c': 2004, 'd': 2008})
print(terceiros_jogos)
# Out:
# Criando uma instância de Series a partir de um dicionário
# a    1996
# b    2000
# c    2004
# d    2008
# dtype: int64

# %% [markdown]
# Exercício considerando o seguinte texto:
#
#
#
# "Primeiro jogo eletrônico (não comercial): Considera-se frequentemente o Tennis for Two, criado em 1958 por William A. Higinbotham em um osciloscópio, para entretenimento dos visitantes de um laboratório. Outros jogos acadêmicos, como o xadrez programado por Alan Turing e o OXO (versão do jogo da velha) de 1952, também são marcos iniciais. Primeiro console de videogame comercial: O Magnavox Odyssey, desenvolvido por Ralph Baer (considerado o "pai do videogame") e lançado em 1972, é amplamente reconhecido como o primeiro console doméstico comercializado no mundo. Ele vinha com jogos que utilizavam cartuchos e sobreposições de tela para simular cores e cenários. Primeiro jogo de fliperama (arcade): O primeiro jogo de fliperama foi o Computer Space, lançado em 1971. O sucesso comercial só veio depois, em 1972, com o lançamento de Pong pela Atari" -Crie uma Serie a partir de um dicionario -O dicionário terá como chave um apelido para o jogo em uma palavra pequena e um valor que o lançamento do jogo

# %%
# resultado do exercício
jogos_dict = {
    'oxo': 1952,
    'tennis_for_two': 1958,
    'computer_space': 1971,
    'magnavox_odyssey': 1972,    
    'pong': 1972
}
jogos_serie = pd.Series(jogos_dict)
print(jogos_serie)
# Out:
# oxo                 1952
# tennis_for_two      1958
# computer_space      1971
# magnavox_odyssey    1972
# pong                1972
# dtype: int64

# %%
# buscar um jogo pelo seu apelido
print("Ano de lançamento do jogo Pong:", jogos_serie['pong'])

# %%
# buscar outro jogo pelo seu apelido
print("Ano de lançamento do jogo Tennis for Two:", jogos_serie['tennis_for_two'])

# %%
# que tal visualizar os tipos de dados usando dtype
print("Tipos de dados da Series jogos_serie:")
print(jogos_serie.dtypes)

# %%
# podemos visualizar o cabeçalho do dataframe porém com quantidades diferentes
print("Cabeçalho do DataFrame com 3 linhas:")   
print(df.head(3))

# %%
# quanto de entrada tempos no dataset
print("Quantidade de entradas no dataset:", len(df))

# %%
# como podemos examinar os tipos de dados do dataframe
print("Tipos de dados do DataFrame:")
print(df.dtypes)

# %%
# e a função describe
print("Estatísticas descritivas do DataFrame:") 
print(df.describe())

# %%
# acessando uma coluna específica
print("Acessando a coluna 'salario':")  
print(df['Salario'])

# %%
# Fatiando o dataframe
print("Fatiando o DataFrame - primeiras 5 linhas da coluna 'Salario':")
print(df['Salario'][0:5])

# %%
# Uma outra forma de acessar uma coluna específica fatiando o dataframe
print("Outra forma de fatiar o DataFrame - primeiras 5 linhas da coluna 'Salario':")
print(df.Salario[0:5])

# %%
# quero mostrar só as colunas
print("Mostrando apenas as colunas 'Ano' e 'Salario':")
print(df.columns)

# %% [markdown]
# Cada coluna tem um tipo diferente na estatística descritiva
#
# O que é estatística descritiva
#
# O que é população?
#
# O que é amostra?
#
# O que é média?
#
# O que é mediana?
#
# O que é desvio padrão?

# %%
# informações sobre o dataframe
df.info()

# %% [markdown]
# #Exercício
#
# "Entre no Kaggle, busque um dataset que trate de uso de jogos e dispositivos" Abra esse dataset em um novo notebook e implemente uma análise exploratória Seu desafio será definir os tipos de variáveis encontradas e o significado de cada variável.
#
# #Exercício
#
# "Crie uma proposta de questionário para uma turma do SENAC sobre jogos, inicie com a sua turma" O objetivo é que tenho que lançar um novo jogo indie e quero saber se é melhor lançar PC, Console ou Mobile. Crie um questionário para gerarmos uma análise descritiva desses dados.
