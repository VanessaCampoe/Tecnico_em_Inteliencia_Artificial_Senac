# %%
 exercicio - Estastistica descritiva (medida de tendencias central )

Um pesquisador ficou em determinado cruzamento durante 18 dias. Nesse cruzamento movimentado em media o nivel  de ruido (em decibes)


Media

# %%
# carga o dataset 
# calcular a medida 
# df. campo.mean()

# %%
import pandas as pd

# %%
df = pd.read_csv("datasets/dataset_ruido.csv")

# %%
df.head()
# Out:
#    numero do dia  nivel ruido (dB)
# 0              1                85
# 1              2                92
# 2              3                95
# 3              4                98
# 4              5                99

# %%
df.tail()
# Out:
#     numero do dia  nivel ruido (dB)
# 13             14               120
# 14             15               120
# 15             16               122
# 16             17               125
# 17             18               127

# %%
df.tail()
# Out:
#     numero do dia  nivel ruido (dB)
# 13             14               120
# 14             15               120
# 15             16               122
# 16             17               125
# 17             18               127

# %%
df['nivel ruido (dB)'].mean()
# Out:
# np.float64(108.44444444444444)
